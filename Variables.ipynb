# %% [markdown]
#  # Data Analysis

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print('Data Analysis')
# Out:
# Data Analysis

# %%
x = 4
print (x)
# Out:
# 4

# %%
type(x)
# Out:
# int

# %%
y = "Hello Suraj"
print(y)
# Out:
# Hello Suraj

# %%
y = 'Mini Chocolate chip'
print(y)
# Out:
# Mini Chocolate chip

# %%
type(y)
# Out:
# str

# %%
# Case Sensativity
y = 'Chocolate'
Y = 'Mini Chocolate Chip'
print(Y)
# Out:
# Mini Chocolate Chip

# %%
# Assign multiple values to multiple varibles

x,y,z = 'Chocolates','Vanilla','Rocky Red'

print(x)
print(y)
print(z)
# Out:
# Chocolates
# Vanilla
# Rocky Red

# %%
# Assign one value to multiple variables

x = y = z = 'Root Beer Float'

print(x)
print(y)
print(z)
# Out:
# Root Beer Float
# Root Beer Float
# Root Beer Float

# %%
# Assign one value to single variable

x = y = z = 'Root Beer Float'

print(x,y,z)
# Out:
# Root Beer Float Root Beer Float Root Beer Float

# %%
ice_cream = ['Chocolate','Vanilla','Rocky Road']

x,y,z = ice_cream

print(x)
print(y)
print(z)
# Out:
# Chocolate
# Vanilla
# Rocky Road

# %%
#Assign one value to multiple variables

x = y = z = 'Root Beer Float'

print(x)
print(y)
print(z)
# Out:
# Root Beer Float
# Root Beer Float
# Root Beer Float

# %%
# Camel Case
# Test Variable Case

testVariableCase = 'Vanilla Swirl'

# %%
#Pascal Case

TestVariableCase = 'Vanilla Swirl'

# %%
# Snake Case

test_variable_case = 'Vanilla Swirl'

# %%
# Good Ways to Write Variables

testvar = 'Vanilla Swirl'
test_var = 'Vanila Swirl'
_test_var = 'Vanila Swirl'
testVar = 'Vanila Swirl'
TestVar = 'Vanila Swirl'
testVar2 = 'Vanila Swirl'

# %%
#Bad ways to write variables

2testVar = 'Vanilla Swirl'
test-Var2 = 'Vanilla Swirl'
test Var2 = 'Vanilla Swirl'
test,Var2 = 'Vanilla Swirl'

# %%
x = 'Ice Cream is my favourite' + 2

print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 x = 'Ice Cream is my favourite' + 2
#       3 print(x)
#
# TypeError: can only concatenate str (not "int") to str

# %%
y = 5 + 6
print(y)
# Out:
# 11

# %%
x = 'Ice Craem'
y = ' is'
z= ' my favourite'

print(x+y+z)
# Out:
# Ice Craem is my favourite

# %%
x = 1
y = 2
z = 3

print(x,y,z)
print(x+y+z)
# Out:
# 1 2 3
# 6

# %%
x = 'Ice Cream'
y= 2 

print(x,y)
# Out:
# Ice Cream 2
